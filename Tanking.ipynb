# %%
cd programNick
# Out:
# [WinError 2] The system cannot find the file specified: 'programNick'
# C:\Users\nicho\programNick

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import seaborn as sns
from datetime import datetime

# %%
team_record = pd.read_csv('Team_Records.csv')

# %%
team_record.drop(['Lg', 'SRS', 'Pace', 'Rel_Pace', 'Rel_ORtg', 'Rel_DRtg', 'Coaches', 'Top WS'], axis=1, inplace=True)
team_record
# Out:
#        Season                 Team   W   L   W/L%  Finish   ORtg   DRtg  \
# 0     2017-18       Boston Celtics  29  10  0.744       1  108.0  102.8
# 1     2016-17      Boston Celtics*  53  29  0.646       1  111.2  108.4
# 2     2015-16      Boston Celtics*  48  34  0.585       2  106.8  103.6
# 3     2014-15      Boston Celtics*  40  42  0.488       2  104.7  104.5
# 4     2013-14       Boston Celtics  25  57  0.305       4  102.9  107.7
# ...       ...                  ...  ..  ..    ...     ...    ...    ...
# 1478  1999-00  Vancouver Grizzlies  22  60  0.268       7  102.3  108.5
# 1479  1998-99  Vancouver Grizzlies   8  42  0.160       7   98.4  107.9
# 1480  1997-98  Vancouver Grizzlies  19  63  0.232       6  104.1  112.0
# 1481  1996-97  Vancouver Grizzlies  14  68  0.171       7  100.3  111.8
# 1482  1995-96  Vancouver Grizzlies  15  67  0.183       7   97.6  108.5
#
#                     Playoffs
# 0                        NaN
# 1       Lost E. Conf. Finals
# 2     Lost E. Conf. 1st Rnd.
# 3     Lost E. Conf. 1st Rnd.
# 4                        NaN
# ...                      ...
# 1478                     NaN
# 1479                     NaN
# 1480                     NaN
# 1481                     NaN
# 1482                     NaN
#
# [1483 rows x 9 columns]

# %%
#teams that did not make the playoffs had blank cells, added lottery to know which teams made the lottery 
team_record1 = team_record.fillna('Lottery')
team_record1
# Out:
#        Season                 Team   W   L   W/L%  Finish   ORtg   DRtg  \
# 0     2017-18       Boston Celtics  29  10  0.744       1  108.0  102.8
# 1     2016-17      Boston Celtics*  53  29  0.646       1  111.2  108.4
# 2     2015-16      Boston Celtics*  48  34  0.585       2  106.8  103.6
# 3     2014-15      Boston Celtics*  40  42  0.488       2  104.7  104.5
# 4     2013-14       Boston Celtics  25  57  0.305       4  102.9  107.7
# ...       ...                  ...  ..  ..    ...     ...    ...    ...
# 1478  1999-00  Vancouver Grizzlies  22  60  0.268       7  102.3  108.5
# 1479  1998-99  Vancouver Grizzlies   8  42  0.160       7   98.4  107.9
# 1480  1997-98  Vancouver Grizzlies  19  63  0.232       6  104.1  112.0
# 1481  1996-97  Vancouver Grizzlies  14  68  0.171       7  100.3  111.8
# 1482  1995-96  Vancouver Grizzlies  15  67  0.183       7   97.6  108.5
#
#                     Playoffs
# 0                    Lottery
# 1       Lost E. Conf. Finals
# 2     Lost E. Conf. 1st Rnd.
# 3     Lost E. Conf. 1st Rnd.
# 4                    Lottery
# ...                      ...
# 1478                 Lottery
# 1479                 Lottery
# 1480                 Lottery
# 1481                 Lottery
# 1482                 Lottery
#
# [1483 rows x 9 columns]

# %%
#get teams are in the lottery after the season has finished 
team_record1[team_record1['Playoffs'] == 'Lottery']
# Out:
#        Season                 Team   W   L   W/L%  Finish   ORtg   DRtg  \
# 0     2017-18       Boston Celtics  29  10  0.744       1  108.0  102.8
# 4     2013-14       Boston Celtics  25  57  0.305       4  102.9  107.7
# 11    2006-07       Boston Celtics  24  58  0.293       5  103.2  106.9
# 12    2005-06       Boston Celtics  33  49  0.402       3  105.2  106.9
# 17    2000-01       Boston Celtics  36  46  0.439       5  101.4  103.7
# ...       ...                  ...  ..  ..    ...     ...    ...    ...
# 1478  1999-00  Vancouver Grizzlies  22  60  0.268       7  102.3  108.5
# 1479  1998-99  Vancouver Grizzlies   8  42  0.160       7   98.4  107.9
# 1480  1997-98  Vancouver Grizzlies  19  63  0.232       6  104.1  112.0
# 1481  1996-97  Vancouver Grizzlies  14  68  0.171       7  100.3  111.8
# 1482  1995-96  Vancouver Grizzlies  15  67  0.183       7   97.6  108.5
#
#      Playoffs
# 0     Lottery
# 4     Lottery
# 11    Lottery
# 12    Lottery
# 17    Lottery
# ...       ...
# 1478  Lottery
# 1479  Lottery
# 1480  Lottery
# 1481  Lottery
# 1482  Lottery
#
# [623 rows x 9 columns]

# %%
team_record = team_record1[team_record1['Playoffs'] == 'Lottery']
team_record
# Out:
#        Season                 Team   W   L   W/L%  Finish   ORtg   DRtg  \
# 0     2017-18       Boston Celtics  29  10  0.744       1  108.0  102.8
# 4     2013-14       Boston Celtics  25  57  0.305       4  102.9  107.7
# 11    2006-07       Boston Celtics  24  58  0.293       5  103.2  106.9
# 12    2005-06       Boston Celtics  33  49  0.402       3  105.2  106.9
# 17    2000-01       Boston Celtics  36  46  0.439       5  101.4  103.7
# ...       ...                  ...  ..  ..    ...     ...    ...    ...
# 1478  1999-00  Vancouver Grizzlies  22  60  0.268       7  102.3  108.5
# 1479  1998-99  Vancouver Grizzlies   8  42  0.160       7   98.4  107.9
# 1480  1997-98  Vancouver Grizzlies  19  63  0.232       6  104.1  112.0
# 1481  1996-97  Vancouver Grizzlies  14  68  0.171       7  100.3  111.8
# 1482  1995-96  Vancouver Grizzlies  15  67  0.183       7   97.6  108.5
#
#      Playoffs
# 0     Lottery
# 4     Lottery
# 11    Lottery
# 12    Lottery
# 17    Lottery
# ...       ...
# 1478  Lottery
# 1479  Lottery
# 1480  Lottery
# 1481  Lottery
# 1482  Lottery
#
# [623 rows x 9 columns]

# %%
team_record = team_record.astype(str)

# %%
#get rid of the seasons that I will not be using for this assignment 
team_record[team_record['Season'].str.contains('1946-47|1947-48|1948-49|1949-50|1950-51|1951-52|1952-53|1953-54|1954-55|1955-56|1956-57|1957-58|1958-59|1959-60|'
                                              +'1960-61|1961-62|1962-63|1963-64|1964-65|1965-66|1966-67|1967-68|1968-69|1969-70|1970-71|1971-72|1972-73|1973-74|'
                                               +'1974-75|1975-76|1976-77|1977-78|1978-79|1979-80|1980-81|1981-82|1982-83|1983-84|1984-85|1985-86|1986-87|1987-88|'
                                               +'1988-89|1989-90|1990-91|1991-92|1992-93|1993-94|1994-95|1995-96|1996-97|1997-98|1998-99|1999-00|2000-01|2001-02|'
                                               +'2002-03|2003-04|2004-05|2005-06|2006-07|2017-18') == False]
# Out:
#        Season               Team   W   L   W/L% Finish   ORtg   DRtg Playoffs
# 4     2013-14     Boston Celtics  25  57  0.305      4  102.9  107.7  Lottery
# 77    2012-13    Toronto Raptors  34  48  0.415      5  105.9  107.5  Lottery
# 78    2011-12    Toronto Raptors  23  43  0.348      4  100.8  104.5  Lottery
# 79    2010-11    Toronto Raptors  22  60  0.268      5  106.1  112.9  Lottery
# 80    2009-10    Toronto Raptors  40  42  0.488      2  111.3  113.2  Lottery
# ...       ...                ...  ..  ..    ...    ...    ...    ...      ...
# 1423  2016-17   Dallas Mavericks  33  49  0.402      5  105.6  108.8  Lottery
# 1427  2012-13   Dallas Mavericks  41  41    0.5      4  105.9  106.5  Lottery
# 1468  2009-10  Memphis Grizzlies  40  42  0.488      4  108.3  109.9  Lottery
# 1469  2008-09  Memphis Grizzlies  24  58  0.293      5  103.5  109.5  Lottery
# 1470  2007-08  Memphis Grizzlies  22  60  0.268      5  105.0  111.4  Lottery
#
# [140 rows x 9 columns]

# %%
worst_team = team_record.groupby(['Season', 'Team'])['W/L%'].min()

# %%
#Sacramento Kings had the worst record this year
worst_team['2008-09']
# Out:
# Team
# Charlotte Bobcats         0.427
# Golden State Warriors     0.354
# Indiana Pacers            0.439
# Los Angeles Clippers      0.232
# Memphis Grizzlies         0.293
# Milwaukee Bucks           0.415
# Minnesota Timberwolves    0.293
# New Jersey Nets           0.415
# New York Knicks            0.39
# Oklahoma City Thunder      0.28
# Phoenix Suns              0.561
# Sacramento Kings          0.207
# Toronto Raptors           0.402
# Washington Wizards        0.232
# Name: W/L%, dtype: object

# %%
#New Jersey Nets had the worst record this year
worst_team['2009-10']
# Out:
# Team
# Detroit Pistons           0.329
# Golden State Warriors     0.317
# Houston Rockets           0.512
# Indiana Pacers             0.39
# Los Angeles Clippers      0.354
# Memphis Grizzlies         0.488
# Minnesota Timberwolves    0.183
# New Jersey Nets           0.146
# New Orleans Hornets       0.451
# New York Knicks           0.354
# Philadelphia 76ers        0.329
# Sacramento Kings          0.305
# Toronto Raptors           0.488
# Washington Wizards        0.317
# Name: W/L%, dtype: object

# %%
#Minnesota Timberwolves had the worst record this year
worst_team['2010-11']
# Out:
# Team
# Charlotte Bobcats         0.415
# Cleveland Cavaliers       0.232
# Detroit Pistons           0.366
# Golden State Warriors     0.439
# Houston Rockets           0.524
# Los Angeles Clippers       0.39
# Milwaukee Bucks           0.427
# Minnesota Timberwolves    0.207
# New Jersey Nets           0.293
# Phoenix Suns              0.488
# Sacramento Kings          0.293
# Toronto Raptors           0.268
# Utah Jazz                 0.476
# Washington Wizards         0.28
# Name: W/L%, dtype: object

# %%
#Charlotte Bobcats had the worst record this year
worst_team['2011-12']
# Out:
# Team
# Charlotte Bobcats         0.106
# Cleveland Cavaliers       0.318
# Detroit Pistons           0.379
# Golden State Warriors     0.348
# Houston Rockets           0.515
# Milwaukee Bucks            0.47
# Minnesota Timberwolves    0.394
# New Jersey Nets           0.333
# New Orleans Hornets       0.318
# Phoenix Suns                0.5
# Portland Trail Blazers    0.424
# Sacramento Kings          0.333
# Toronto Raptors           0.348
# Washington Wizards        0.303
# Name: W/L%, dtype: object

# %%
#Orlando Magic had the worst record this year
worst_team['2012-13']
# Out:
# Team
# Charlotte Bobcats         0.256
# Cleveland Cavaliers       0.293
# Dallas Mavericks            0.5
# Detroit Pistons           0.354
# Minnesota Timberwolves    0.378
# New Orleans Hornets       0.329
# Orlando Magic             0.244
# Philadelphia 76ers        0.415
# Phoenix Suns              0.305
# Portland Trail Blazers    0.402
# Sacramento Kings          0.341
# Toronto Raptors           0.415
# Utah Jazz                 0.524
# Washington Wizards        0.354
# Name: W/L%, dtype: object

# %%
#Milwaukee Bucks had the worst record this year
worst_team['2013-14']
# Out:
# Team
# Boston Celtics            0.305
# Cleveland Cavaliers       0.402
# Denver Nuggets            0.439
# Detroit Pistons           0.354
# Los Angeles Lakers        0.329
# Milwaukee Bucks           0.183
# Minnesota Timberwolves    0.488
# New Orleans Pelicans      0.415
# New York Knicks           0.451
# Orlando Magic              0.28
# Philadelphia 76ers        0.232
# Phoenix Suns              0.585
# Sacramento Kings          0.341
# Utah Jazz                 0.305
# Name: W/L%, dtype: object

# %%
#Minnesota Timberwolves had the worst record this year
worst_team['2014-15']
# Out:
# Team
# Charlotte Hornets         0.402
# Denver Nuggets            0.366
# Detroit Pistons            0.39
# Indiana Pacers            0.463
# Los Angeles Lakers        0.256
# Miami Heat                0.451
# Minnesota Timberwolves    0.195
# New York Knicks           0.207
# Oklahoma City Thunder     0.549
# Orlando Magic             0.305
# Philadelphia 76ers         0.22
# Phoenix Suns              0.476
# Sacramento Kings          0.354
# Utah Jazz                 0.463
# Name: W/L%, dtype: object

# %%
#Philadelphia 76ers had the worst record this year
worst_team['2015-16']
# Out:
# Team
# Brooklyn Nets             0.256
# Chicago Bulls             0.512
# Denver Nuggets            0.402
# Los Angeles Lakers        0.207
# Milwaukee Bucks           0.402
# Minnesota Timberwolves    0.354
# New Orleans Pelicans      0.366
# New York Knicks            0.39
# Orlando Magic             0.427
# Philadelphia 76ers        0.122
# Phoenix Suns               0.28
# Sacramento Kings          0.402
# Utah Jazz                 0.488
# Washington Wizards          0.5
# Name: W/L%, dtype: object

# %%
#Brooklyn Nets had the worst record this year
worst_team['2016-17']
# Out:
# Team
# Brooklyn Nets             0.244
# Charlotte Hornets         0.439
# Dallas Mavericks          0.402
# Denver Nuggets            0.488
# Detroit Pistons           0.451
# Los Angeles Lakers        0.317
# Miami Heat                  0.5
# Minnesota Timberwolves    0.378
# New Orleans Pelicans      0.415
# New York Knicks           0.378
# Orlando Magic             0.354
# Philadelphia 76ers        0.341
# Phoenix Suns              0.293
# Sacramento Kings           0.39
# Name: W/L%, dtype: object

# %%
#The following few lines of code are for teams who had the worst record and their records afterwards to see if they got any better or worse
Sacramento = team_record.loc[((team_record['Season'] == '2008-09') & (team_record['Team'] == 'Sacramento Kings'))|((team_record['Season'] == '2009-10') & (team_record['Team'] == 'Sacramento Kings'))|
                                  ((team_record['Season'] == '2010-11') & (team_record['Team'] == 'Sacramento Kings'))|((team_record['Season'] == '2011-12') & (team_record['Team'] == 'Sacramento Kings'))]
Sacramento.sort_values('Season')
# Out:
#       Season              Team   W   L   W/L% Finish   ORtg   DRtg Playoffs
# 960  2008-09  Sacramento Kings  17  65  0.207      5  105.5  114.7  Lottery
# 959  2009-10  Sacramento Kings  25  57  0.305      5  105.3  109.9  Lottery
# 958  2010-11  Sacramento Kings  24  58  0.293      5  103.5  109.0  Lottery
# 957  2011-12  Sacramento Kings  22  44  0.333      5  103.8  109.8  Lottery

# %%
Nets = team_record.loc[((team_record['Season'] == '2009-10') & (team_record['Team'] == 'New Jersey Nets'))|((team_record['Season'] == '2010-11') & (team_record['Team'] == 'New Jersey Nets'))|
                        ((team_record['Season'] == '2011-12') & (team_record['Team'] == 'New Jersey Nets'))|((team_record['Season'] == '2012-13') & (team_record['Team'] == 'New Jersey Nets'))]
Nets.sort_values('Season')
# Out:
#       Season             Team   W   L   W/L% Finish   ORtg   DRtg Playoffs
# 244  2009-10  New Jersey Nets  12  70  0.146      5  100.6  110.5  Lottery
# 243  2010-11  New Jersey Nets  24  58  0.293      4  103.1  109.9  Lottery
# 242  2011-12  New Jersey Nets  22  44  0.333      5  102.9  109.6  Lottery

# %%
Timberwolves = team_record.loc[((team_record['Season'] == '2010-11') & (team_record['Team'] == 'Minnesota Timberwolves'))|((team_record['Season'] == '2011-12') & (team_record['Team'] == 'Minnesota Timberwolves'))|
                               ((team_record['Season'] == '2012-13') & (team_record['Team'] == 'Minnesota Timberwolves'))|((team_record['Season'] == '2013-14') & (team_record['Team'] == 'Minnesota Timberwolves'))]
Timberwolves.sort_values('Season')
# Out:
#       Season                    Team   W   L   W/L% Finish   ORtg   DRtg  \
# 294  2010-11  Minnesota Timberwolves  17  65  0.207      5  104.2  111.1
# 293  2011-12  Minnesota Timberwolves  26  40  0.394      5  104.3  106.6
# 292  2012-13  Minnesota Timberwolves  31  51  0.378      5  102.9  105.4
# 291  2013-14  Minnesota Timberwolves  40  42  0.488      3  108.9  106.2
#
#     Playoffs
# 294  Lottery
# 293  Lottery
# 292  Lottery
# 291  Lottery

# %%
Bobcats = team_record.loc[((team_record['Season'] == '2011-12') & (team_record['Team'] == 'Charlotte Bobcats'))|((team_record['Season'] == '2012-13') & (team_record['Team'] == 'Charlotte Bobcats'))|
                          ((team_record['Season'] == '2013-14') & (team_record['Team'] == 'Charlotte Hornets'))|((team_record['Season'] == '2014-15') & (team_record['Team'] == 'Charlotte Hornets'))]
Bobcats.sort_values('Season')
# Out:
#        Season               Team   W   L   W/L% Finish   ORtg   DRtg Playoffs
# 1184  2011-12  Charlotte Bobcats   7  59  0.106      5   95.2  110.4  Lottery
# 1183  2012-13  Charlotte Bobcats  21  61  0.256      4  101.5  111.5  Lottery
# 1181  2014-15  Charlotte Hornets  33  49  0.402      4  100.1  103.5  Lottery

# %%
Magic = team_record.loc[((team_record['Season'] == '2012-13') & (team_record['Team'] == 'Orlando Magic'))|((team_record['Season'] == '2013-14') & (team_record['Team'] == 'Orlando Magic'))|
                        ((team_record['Season'] == '2014-15') & (team_record['Team'] == 'Orlando Magic'))|((team_record['Season'] == '2015-16') & (team_record['Team'] == 'Orlando Magic'))]
Magic.sort_values('Season')
# Out:
#        Season           Team   W   L   W/L% Finish   ORtg   DRtg Playoffs
# 1211  2012-13  Orlando Magic  20  62  0.244      5  101.6  109.1  Lottery
# 1210  2013-14  Orlando Magic  23  59   0.28      5  101.7  107.4  Lottery
# 1209  2014-15  Orlando Magic  25  57  0.305      5  101.6  107.7  Lottery
# 1208  2015-16  Orlando Magic  35  47  0.427      5  105.1  106.8  Lottery

# %%
Bucks = team_record.loc[((team_record['Season'] == '2013-14') & (team_record['Team'] == 'Milwaukee Bucks'))|((team_record['Season'] == '2014-15') & (team_record['Team'] == 'Milwaukee Bucks'))|
                        ((team_record['Season'] == '2015-16') & (team_record['Team'] == 'Milwaukee Bucks'))|((team_record['Season'] == '2016-17') & (team_record['Team'] == 'Milwaukee Bucks'))]
Bucks.sort_values('Season')
# Out:
#       Season             Team   W   L   W/L% Finish   ORtg   DRtg Playoffs
# 632  2013-14  Milwaukee Bucks  15  67  0.183      5  103.0  111.8  Lottery
# 630  2015-16  Milwaukee Bucks  33  49  0.402      5  104.3  108.7  Lottery

# %%
Philly = team_record.loc[((team_record['Season'] == '2015-16') & (team_record['Team'] == 'Philadelphia 76ers'))|((team_record['Season'] == '2016-17') & (team_record['Team'] == 'Philadelphia 76ers'))|
                         ((team_record['Season'] == '2017-18') & (team_record['Team'] == 'Philadelphia 76ers'))]
Philly.sort_values('Season')
# Out:
#       Season                Team   W   L   W/L% Finish   ORtg   DRtg Playoffs
# 169  2015-16  Philadelphia 76ers  10  72  0.122      5   98.8  109.2  Lottery
# 168  2016-17  Philadelphia 76ers  28  54  0.341      4  103.2  108.9  Lottery
# 167  2017-18  Philadelphia 76ers  15  19  0.441      4  105.8  106.8  Lottery

# %%
worst_team_year = team_record.loc[((team_record['Season'] == '2008-09') & (team_record['Team'] == 'Sacramento Kings'))|((team_record['Season'] == '2009-10') & (team_record['Team'] == 'New Jersey Nets'))|
                                 ((team_record['Season'] == '2010-11') & (team_record['Team'] == 'Minnesota Timberwolves'))|((team_record['Season'] == '2011-12') & (team_record['Team'] == 'Charlotte Bobcats'))|
                                 ((team_record['Season'] == '2012-13') & (team_record['Team'] == 'Orlando Magic'))|((team_record['Season'] == '2013-14') & (team_record['Team'] == 'Milwaukee Bucks'))|
                                 ((team_record['Season'] == '2014-15') & (team_record['Team'] == 'Minnesota Timberwolves'))|((team_record['Season'] == '2015-16') & (team_record['Team'] == 'Philadelphia 76ers'))|
                                 ((team_record['Season'] == '2016-17') & (team_record['Team'] == 'Brooklyn Nets'))]

# %%
#the worst team each year into a dataframe
worst_team_year.sort_values('Season')
# Out:
#        Season                    Team   W   L   W/L% Finish   ORtg   DRtg  \
# 960   2008-09        Sacramento Kings  17  65  0.207      5  105.5  114.7
# 244   2009-10         New Jersey Nets  12  70  0.146      5  100.6  110.5
# 294   2010-11  Minnesota Timberwolves  17  65  0.207      5  104.2  111.1
# 1184  2011-12       Charlotte Bobcats   7  59  0.106      5   95.2  110.4
# 1211  2012-13           Orlando Magic  20  62  0.244      5  101.6  109.1
# 632   2013-14         Milwaukee Bucks  15  67  0.183      5  103.0  111.8
# 290   2014-15  Minnesota Timberwolves  16  66  0.195      5  102.9  112.2
# 169   2015-16      Philadelphia 76ers  10  72  0.122      5   98.8  109.2
# 237   2016-17           Brooklyn Nets  20  62  0.244      5  104.1  110.7
#
#      Playoffs
# 960   Lottery
# 244   Lottery
# 294   Lottery
# 1184  Lottery
# 1211  Lottery
# 632   Lottery
# 290   Lottery
# 169   Lottery
# 237   Lottery

# %%
team_record.set_index(['Season'], drop = True)
# Out:
#                         Team   W   L   W/L% Finish   ORtg   DRtg Playoffs
# Season
# 2017-18       Boston Celtics  29  10  0.744      1  108.0  102.8  Lottery
# 2013-14       Boston Celtics  25  57  0.305      4  102.9  107.7  Lottery
# 2006-07       Boston Celtics  24  58  0.293      5  103.2  106.9  Lottery
# 2005-06       Boston Celtics  33  49  0.402      3  105.2  106.9  Lottery
# 2000-01       Boston Celtics  36  46  0.439      5  101.4  103.7  Lottery
# ...                      ...  ..  ..    ...    ...    ...    ...      ...
# 1999-00  Vancouver Grizzlies  22  60  0.268      7  102.3  108.5  Lottery
# 1998-99  Vancouver Grizzlies   8  42   0.16      7   98.4  107.9  Lottery
# 1997-98  Vancouver Grizzlies  19  63  0.232      6  104.1  112.0  Lottery
# 1996-97  Vancouver Grizzlies  14  68  0.171      7  100.3  111.8  Lottery
# 1995-96  Vancouver Grizzlies  15  67  0.183      7   97.6  108.5  Lottery
#
# [623 rows x 8 columns]

# %%
first_pick_teams = team_record.loc[((team_record['Season'] == '2008-09') & (team_record['Team'] == 'Los Angeles Clippers'))|((team_record['Season'] == '2009-10') & (team_record['Team'] == 'Washington Wizards'))|
                                  ((team_record['Season'] == '2010-11') & (team_record['Team'] == 'Cleveland Cavaliers'))|((team_record['Season'] == '2011-12') & (team_record['Team'] == 'New Orleans Hornets'))|
                                  ((team_record['Season'] == '2012-13') & (team_record['Team'] == 'Cleveland Cavaliers'))|((team_record['Season'] == '2013-14') & (team_record['Team'] == 'Cleveland Cavaliers'))|
                                  ((team_record['Season'] == '2014-15') & (team_record['Team'] == 'Minnesota Timberwolves'))|((team_record['Season'] == '2015-16') & (team_record['Team'] == 'Philadelphia 76ers'))|
                                  ((team_record['Season'] == '2016-17') & (team_record['Team'] == 'Brooklyn Nets'))]

# %%
#teams that won the lottery 
first_pick_teams.sort_values('Season')
# Out:
#        Season                    Team   W   L   W/L% Finish   ORtg   DRtg  \
# 862   2008-09    Los Angeles Clippers  19  63  0.232      4  102.3  111.7
# 1099  2009-10      Washington Wizards  26  56  0.317      5  104.2  109.4
# 517   2010-11     Cleveland Cavaliers  19  63  0.232      5  102.2  111.8
# 1412  2011-12     New Orleans Hornets  21  45  0.318      5  100.9  105.1
# 515   2012-13     Cleveland Cavaliers  24  58  0.293      5  104.3  109.4
# 514   2013-14     Cleveland Cavaliers  33  49  0.402      3  104.2  107.7
# 290   2014-15  Minnesota Timberwolves  16  66  0.195      5  102.9  112.2
# 169   2015-16      Philadelphia 76ers  10  72  0.122      5   98.8  109.2
# 237   2016-17           Brooklyn Nets  20  62  0.244      5  104.1  110.7
#
#      Playoffs
# 862   Lottery
# 1099  Lottery
# 517   Lottery
# 1412  Lottery
# 515   Lottery
# 514   Lottery
# 290   Lottery
# 169   Lottery
# 237   Lottery

# %%
#import lottery pick csv
lottery_picks = pd.read_csv('lottery-picks.csv')

# %%
lottery_picks.rename( columns={'Unnamed: 0':'nickname'}, inplace=True )

# %%
#dropping unnecessary columns
lottery_picks.drop(['college_name', 'bpm', 'vorp', 'nickname'], axis=1, inplace=True)

# %%
lottery_picks
# Out:
#      pick_overall  Year team_id             player  seasons       g       mp  \
# 0               1  1995     GSW          Joe Smith     16.0  1030.0  27022.0
# 1               2  1995     LAC    Antonio McDyess     15.0  1015.0  28053.0
# 2               3  1995     PHI   Jerry Stackhouse     18.0   970.0  30222.0
# 3               4  1995     WSB    Rasheed Wallace     16.0  1109.0  36243.0
# 4               5  1995     MIN      Kevin Garnett     21.0  1462.0  50418.0
# ..            ...   ...     ...                ...      ...     ...      ...
# 359            10  2020     PHO        Jalen Smith      NaN     NaN      NaN
# 360            11  2020     SAS      Devin Vassell      NaN     NaN      NaN
# 361            12  2020     SAC  Tyrese Haliburton      NaN     NaN      NaN
# 362            13  2020     NOP         Kira Lewis      NaN     NaN      NaN
# 363            14  2020     BOS      Aaron Nesmith      NaN     NaN      NaN
#
#          pts      trb     ast  fg_pct  fg3_pct  ft_pct  mp_per_g  pts_per_g  \
# 0    11208.0   6575.0  1010.0   0.455    0.238   0.790      26.2       10.9
# 1    12227.0   7638.0  1300.0   0.497    0.117   0.670      27.6       12.0
# 2    16409.0   3067.0  3240.0   0.409    0.309   0.822      31.2       16.9
# 3    16006.0   7404.0  1994.0   0.467    0.336   0.721      32.7       14.4
# 4    26071.0  14662.0  5445.0   0.497    0.275   0.789      34.5       17.8
# ..       ...      ...     ...     ...      ...     ...       ...        ...
# 359      NaN      NaN     NaN     NaN      NaN     NaN       NaN        NaN
# 360      NaN      NaN     NaN     NaN      NaN     NaN       NaN        NaN
# 361      NaN      NaN     NaN     NaN      NaN     NaN       NaN        NaN
# 362      NaN      NaN     NaN     NaN      NaN     NaN       NaN        NaN
# 363      NaN      NaN     NaN     NaN      NaN     NaN       NaN        NaN
#
#      trb_per_g  ast_per_g     ws  ws_per_48
# 0          6.4        1.0   60.3      0.107
# 1          7.5        1.3   69.8      0.119
# 2          3.2        3.3   52.4      0.083
# 3          6.7        1.8  105.1      0.139
# 4         10.0        3.7  191.4      0.182
# ..         ...        ...    ...        ...
# 359        NaN        NaN    NaN        NaN
# 360        NaN        NaN    NaN        NaN
# 361        NaN        NaN    NaN        NaN
# 362        NaN        NaN    NaN        NaN
# 363        NaN        NaN    NaN        NaN
#
# [364 rows x 19 columns]

# %%
#picks of the worst team that year
worst_team_picks = lottery_picks.loc[((lottery_picks['Year'] == 2009) & (lottery_picks['team_id'] == 'SAC'))|((lottery_picks['Year'] == 2010) & (lottery_picks['team_id'] == 'NJN'))|
                  ((lottery_picks['Year'] == 2011) & (lottery_picks['team_id'] == 'MIN'))|((lottery_picks['Year'] == 2012) & (lottery_picks['team_id'] == 'CHA'))|
                  ((lottery_picks['Year'] == 2013) & (lottery_picks['team_id'] == 'ORL'))|((lottery_picks['Year'] == 2014) & (lottery_picks['team_id'] == 'MIL'))|
                  ((lottery_picks['Year'] == 2015) & (lottery_picks['team_id'] == 'MIN'))|((lottery_picks['Year'] == 2016) & (lottery_picks['team_id'] == 'PHI'))|
                  ((lottery_picks['Year'] == 2017) & (lottery_picks['team_id'] == 'BOS'))|((lottery_picks['Year'] == 2018) & (lottery_picks['team_id'] == 'PHO'))]

# %%
worst_team_picks
# Out:
#      pick_overall  Year team_id                  player  seasons      g  \
# 199             4  2009     SAC            Tyreke Evans     10.0  594.0
# 212             3  2010     NJN          Derrick Favors     10.0  683.0
# 225             2  2011     MIN        Derrick Williams      7.0  428.0
# 239             2  2012     CHA  Michael Kidd-Gilchrist      8.0  446.0
# 253             2  2013     ORL          Victor Oladipo      7.0  421.0
# 267             2  2014     MIL           Jabari Parker      6.0  285.0
# 280             1  2015     MIN      Karl-Anthony Towns      5.0  358.0
# 294             1  2016     PHI             Ben Simmons      3.0  217.0
# 310             3  2017     BOS            Jayson Tatum      3.0  225.0
# 322             1  2018     PHO           Deandre Ayton      2.0  109.0
#
#           mp     pts     trb     ast  fg_pct  fg3_pct  ft_pct  mp_per_g  \
# 199  18242.0  9347.0  2720.0  2852.0   0.440    0.323   0.757      30.7
# 212  17510.0  7779.0  5048.0   782.0   0.530    0.207   0.661      25.6
# 225   8864.0  3809.0  1693.0   293.0   0.434    0.300   0.710      20.7
# 239  10978.0  3750.0  2420.0   515.0   0.474    0.272   0.715      24.6
# 253  13888.0  7303.0  1934.0  1645.0   0.441    0.350   0.794      33.0
# 267   8258.0  4255.0  1633.0   593.0   0.493    0.324   0.740      29.0
# 280  12307.0  8113.0  4209.0   992.0   0.534    0.396   0.831      34.4
# 294   7449.0  3553.0  1800.0  1726.0   0.560    0.083   0.593      34.3
# 310   7158.0  3902.0  1339.0   496.0   0.457    0.401   0.829      31.8
# 322   3419.0  1849.0  1165.0   197.0   0.570    0.176   0.748      31.4
#
#      pts_per_g  trb_per_g  ast_per_g    ws  ws_per_48
# 199       15.7        4.6        4.8  28.4      0.075
# 212       11.4        7.4        1.1  53.6      0.147
# 225        8.9        4.0        0.7  14.1      0.076
# 239        8.4        5.4        1.2  21.0      0.092
# 253       17.3        4.6        3.9  24.3      0.084
# 267       14.9        5.7        2.1  13.2      0.077
# 280       22.7       11.8        2.8  50.4      0.197
# 294       16.4        8.3        8.0  24.4      0.157
# 310       17.3        6.0        2.2  18.9      0.127
# 322       17.0       10.7        1.8   9.0      0.126

# %%
worst_team_bar = worst_team_picks.plot.bar(x='Year', y='ws_per_48', rot=0)

# %%
#Get the #1 Draft pick of each year from 2009-2018 of teams that won the lottery 
lottery_picks = lottery_picks[lottery_picks['pick_overall'] == 1]
lottery_picks = lottery_picks.drop(labels=[0, 14, 28, 42, 56, 70, 84, 98, 112, 
                                           126, 140, 154, 168, 182, 336, 350], axis=0)
lottery_picks
# Out:
#      pick_overall  Year team_id              player  seasons      g       mp  \
# 196             1  2009     LAC       Blake Griffin     10.0  622.0  21671.0
# 210             1  2010     WAS           John Wall      9.0  573.0  20545.0
# 224             1  2011     CLE        Kyrie Irving      9.0  528.0  17827.0
# 238             1  2012     NOH       Anthony Davis      8.0  528.0  18239.0
# 252             1  2013     CLE     Anthony Bennett      4.0  151.0   1905.0
# 266             1  2014     CLE      Andrew Wiggins      6.0  454.0  16242.0
# 280             1  2015     MIN  Karl-Anthony Towns      5.0  358.0  12307.0
# 294             1  2016     PHI         Ben Simmons      3.0  217.0   7449.0
# 308             1  2017     PHI      Markelle Fultz      3.0  105.0   2676.0
# 322             1  2018     PHO       Deandre Ayton      2.0  109.0   3419.0
#
#          pts     trb     ast  fg_pct  fg3_pct  ft_pct  mp_per_g  pts_per_g  \
# 196  13479.0  5501.0  2749.0   0.498    0.333   0.694      34.8       21.7
# 210  10879.0  2483.0  5282.0   0.433    0.324   0.781      35.9       19.0
# 224  11842.0  1955.0  3012.0   0.466    0.390   0.877      33.8       22.4
# 238  12677.0  5483.0  1182.0   0.515    0.319   0.802      34.5       24.0
# 252    658.0   472.0    77.0   0.392    0.261   0.670      12.6        4.4
# 266   8943.0  1977.0  1065.0   0.441    0.332   0.732      35.8       19.7
# 280   8113.0  4209.0   992.0   0.534    0.396   0.831      34.4       22.7
# 294   3553.0  1800.0  1726.0   0.560    0.083   0.593      34.3       16.4
# 308   1125.0   351.0   481.0   0.452    0.267   0.677      25.5       10.7
# 322   1849.0  1165.0   197.0   0.570    0.176   0.748      31.4       17.0
#
#      trb_per_g  ast_per_g    ws  ws_per_48
# 196        8.8        4.4  75.2      0.167
# 210        4.3        9.2  44.3      0.104
# 224        3.7        5.7  61.3      0.165
# 238       10.4        2.2  83.1      0.219
# 252        3.1        0.5   0.5      0.013
# 266        4.4        2.3  15.0      0.044
# 280       11.8        2.8  50.4      0.197
# 294        8.3        8.0  24.4      0.157
# 308        3.3        4.6   3.2      0.058
# 322       10.7        1.8   9.0      0.126

# %%
#combine = pd.DataFrame((worst_team_picks, lottery_picks), columns=['pick_overall', 'Year', 'team_id','player','ws_per_48'])

# %%
picks = pd.concat([worst_team_picks,lottery_picks])
picks.sort_values('Year')
# Out:
#      pick_overall  Year team_id                  player  seasons      g  \
# 199             4  2009     SAC            Tyreke Evans     10.0  594.0
# 196             1  2009     LAC           Blake Griffin     10.0  622.0
# 212             3  2010     NJN          Derrick Favors     10.0  683.0
# 210             1  2010     WAS               John Wall      9.0  573.0
# 225             2  2011     MIN        Derrick Williams      7.0  428.0
# 224             1  2011     CLE            Kyrie Irving      9.0  528.0
# 239             2  2012     CHA  Michael Kidd-Gilchrist      8.0  446.0
# 238             1  2012     NOH           Anthony Davis      8.0  528.0
# 253             2  2013     ORL          Victor Oladipo      7.0  421.0
# 252             1  2013     CLE         Anthony Bennett      4.0  151.0
# 267             2  2014     MIL           Jabari Parker      6.0  285.0
# 266             1  2014     CLE          Andrew Wiggins      6.0  454.0
# 280             1  2015     MIN      Karl-Anthony Towns      5.0  358.0
# 280             1  2015     MIN      Karl-Anthony Towns      5.0  358.0
# 294             1  2016     PHI             Ben Simmons      3.0  217.0
# 294             1  2016     PHI             Ben Simmons      3.0  217.0
# 308             1  2017     PHI          Markelle Fultz      3.0  105.0
# 310             3  2017     BOS            Jayson Tatum      3.0  225.0
# 322             1  2018     PHO           Deandre Ayton      2.0  109.0
# 322             1  2018     PHO           Deandre Ayton      2.0  109.0
#
#           mp      pts     trb     ast  fg_pct  fg3_pct  ft_pct  mp_per_g  \
# 199  18242.0   9347.0  2720.0  2852.0   0.440    0.323   0.757      30.7
# 196  21671.0  13479.0  5501.0  2749.0   0.498    0.333   0.694      34.8
# 212  17510.0   7779.0  5048.0   782.0   0.530    0.207   0.661      25.6
# 210  20545.0  10879.0  2483.0  5282.0   0.433    0.324   0.781      35.9
# 225   8864.0   3809.0  1693.0   293.0   0.434    0.300   0.710      20.7
# 224  17827.0  11842.0  1955.0  3012.0   0.466    0.390   0.877      33.8
# 239  10978.0   3750.0  2420.0   515.0   0.474    0.272   0.715      24.6
# 238  18239.0  12677.0  5483.0  1182.0   0.515    0.319   0.802      34.5
# 253  13888.0   7303.0  1934.0  1645.0   0.441    0.350   0.794      33.0
# 252   1905.0    658.0   472.0    77.0   0.392    0.261   0.670      12.6
# 267   8258.0   4255.0  1633.0   593.0   0.493    0.324   0.740      29.0
# 266  16242.0   8943.0  1977.0  1065.0   0.441    0.332   0.732      35.8
# 280  12307.0   8113.0  4209.0   992.0   0.534    0.396   0.831      34.4
# 280  12307.0   8113.0  4209.0   992.0   0.534    0.396   0.831      34.4
# 294   7449.0   3553.0  1800.0  1726.0   0.560    0.083   0.593      34.3
# 294   7449.0   3553.0  1800.0  1726.0   0.560    0.083   0.593      34.3
# 308   2676.0   1125.0   351.0   481.0   0.452    0.267   0.677      25.5
# 310   7158.0   3902.0  1339.0   496.0   0.457    0.401   0.829      31.8
# 322   3419.0   1849.0  1165.0   197.0   0.570    0.176   0.748      31.4
# 322   3419.0   1849.0  1165.0   197.0   0.570    0.176   0.748      31.4
#
#      pts_per_g  trb_per_g  ast_per_g    ws  ws_per_48
# 199       15.7        4.6        4.8  28.4      0.075
# 196       21.7        8.8        4.4  75.2      0.167
# 212       11.4        7.4        1.1  53.6      0.147
# 210       19.0        4.3        9.2  44.3      0.104
# 225        8.9        4.0        0.7  14.1      0.076
# 224       22.4        3.7        5.7  61.3      0.165
# 239        8.4        5.4        1.2  21.0      0.092
# 238       24.0       10.4        2.2  83.1      0.219
# 253       17.3        4.6        3.9  24.3      0.084
# 252        4.4        3.1        0.5   0.5      0.013
# 267       14.9        5.7        2.1  13.2      0.077
# 266       19.7        4.4        2.3  15.0      0.044
# 280       22.7       11.8        2.8  50.4      0.197
# 280       22.7       11.8        2.8  50.4      0.197
# 294       16.4        8.3        8.0  24.4      0.157
# 294       16.4        8.3        8.0  24.4      0.157
# 308       10.7        3.3        4.6   3.2      0.058
# 310       17.3        6.0        2.2  18.9      0.127
# 322       17.0       10.7        1.8   9.0      0.126
# 322       17.0       10.7        1.8   9.0      0.126

# %%
picks.plot.bar('player','ws')
# Out:
# <AxesSubplot:xlabel='player'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Year', y='ws', hue='player',data=picks)
plt.title('Comparing Players Drafted by Worst Team:Winner of Lottery')
plt.xlabel('Year')
plt.ylabel('WS')
# Out:
# Text(0, 0.5, 'WS')
